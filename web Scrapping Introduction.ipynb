# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen 
import logging

# %%
flipkart_url= "https://www.flipkart.com/search?q" + "iphone11"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?qiphone11'

# %%
urlclient=urlopen (flipkart_url)

# %%
urlclient

# %%
flipkart_page=urlclient.read()

# %%
flipkart_page
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.a47a6a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
flipkart_html=bs(flipkart_page,'html.parser')

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
"https://www.flipkart.com/"+"apple-iphone-11-white-128-gb/p/itme32df47ea6742?pid=MOBFWQ6B7KKRXDDS&lid=LSTMOBFWQ6B7KKRXDDSULUZ0N&marketplace=FLIPKART&q=iphone&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=Search&iid=8f2803c7-9eed-4312-8ede-403f2a58ed74.MOBFWQ6B7KKRXDDS.SEARCH&ppt=sp&ppn=sp&ssid=0gpsw79i2o0000001677588209293&qH=0b3f45b266a97d70"
# Out:
# 'https://www.flipkart.com/apple-iphone-11-white-128-gb/p/itme32df47ea6742?pid=MOBFWQ6B7KKRXDDS&lid=LSTMOBFWQ6B7KKRXDDSULUZ0N&marketplace=FLIPKART&q=iphone&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=Search&iid=8f2803c7-9eed-4312-8ede-403f2a58ed74.MOBFWQ6B7KKRXDDS.SEARCH&ppt=sp&ppn=sp&ssid=0gpsw79i2o0000001677588209293&qH=0b3f45b266a97d70'

# %%
bigbox=flipkart_html.findAll("div",{"class":"_1AtVbE col-12-12"})

# %%
len(bigbox)
# Out:
# 15

# %%
del bigbox[0:3]

# %%
productlink="https://www.flipkart.com"+bigbox[3].div.div.div.a["href"]

# %%
product_req=requests.get(productlink)

# %%
productlink
# Out:
# 'https://www.flipkart.com/jolochip-hottest-chip-madness-last-challenge-chips/p/itm5816af6891fbd?pid=CHPGFNXX7FG2BXR2&lid=LSTCHPGFNXX7FG2BXR2OI8X0N&marketplace=FLIPKART&store=search.flipkart.com&srno=b_1_21&otracker=browse&fm=organic&iid=560ff747-940a-44f3-97b3-a26055cbfb3b.CHPGFNXX7FG2BXR2.SEARCH&ppt=None&ppn=None&ssid=df6hc5nbpc0000001677592919848'

# %%
product_html=bs(product_req.text,'html.parser')

# %%
comment_box=product_html.find_all("div",{"class" : "_16PBlm"})

# %%
len(comment_box)
# Out:
# 11

# %%
for i in comment_box:
    print(i.div.div.find_all("p",{"class" : "_2sc7ZR _2V5EHH"})[0].text)
# Out:
# Sri Ram
# Flipkart Customer
# Flipkart Customer
# Flipkart Customer
# laxmi Customer
# Flipkart Customer
# Flipkart Customer
# Flipkart Customer
# Partha Protim Neog
# Hiranmoy Das
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14264\745110659.py in <module>
#       1 for i in comment_box:
# ----> 2     print(i.div.div.find_all("p",{"class" : "_2sc7ZR _2V5EHH"})[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
for i in comment_box:
    print(i.div.div.div.div.text)
# Out:
# 4
# 5
# 1
# 5
# 5
# 5
# 4
# 5
# 2
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14264\2621339938.py in <module>
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
for i in comment_box:
    print(i.div.div.div.text)
# Out:
# 4Very Good
# 5Terrific purchase
# 1Worst experience ever!
# 5Awesome
# 5Worth every penny
# 5Simply awesome
# 4Good quality product
# 5Super!
# 2Expected a better product
# 5Awesome
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14264\3027216305.py in <module>
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
for i in bigbox:
    print("https://www.flipkart.com"+i.div.div.div.a["href"])
