# %%
import pymongo
client = pymongo.MongoClient("mongodb+srv://anuragsingh843125:<jB5fTriLEl4L8mfZ>@cluster0.4xiufvm.mongodb.net/?retryWrites=true&w=majority")
db = client.test

# %%
pip install pymongo
# Out:
# ...
#      ------------------------------------ 382.5/382.5 kB 366.8 kB/s eta 0:00:00
# ...
#      ------------------------------------ 283.7/283.7 kB 389.0 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
db
# Out:
# Database(MongoClient(host=['ac-zhiowyv-shard-00-02.4xiufvm.mongodb.net:27017', 'ac-zhiowyv-shard-00-00.4xiufvm.mongodb.net:27017', 'ac-zhiowyv-shard-00-01.4xiufvm.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-h6axnl-shard-0', tls=True), 'test')

# %%
client = pymongo.MongoClient("mongodb+srv://anuragsingh843125:<jB5fTriLEl4L8mfZ>@cluster0.4xiufvm.mongodb.net/?retryWrites=true&w=majority")

# %%
db=client['pwskills']

# %%
data1 ={"name" : "anu",
        "class" : "data science masters",
        "time": "flexi"}

# %%
coll_pwskills = db["my_record"]

# %%
coll_pwskills.insert_one(data1)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10396\142206259.py in <module>
# ----> 1 coll_pwskills.insert_one(data1)
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session, comment)
#     626         write_concern = self._write_concern_for(session)
#     627         return InsertOneResult(
# --> 628             self._insert_one(
#     629                 document,
#     630                 ordered=True,
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in _insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     567             _check_write_command_response(result)
#     568
# --> 569         self.__database.client._retryable_write(acknowledged, _insert_command, session)
#     570
# ...

# %%
data2 = {"phone_number" : 15452451455, "add" : "bihar"}

# %%
coll_pwskills.insert_one(data2)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10396\4044903247.py in <module>
# ----> 1 coll_pwskills.insert_one(data2)
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session, comment)
#     626         write_concern = self._write_concern_for(session)
#     627         return InsertOneResult(
# --> 628             self._insert_one(
#     629                 document,
#     630                 ordered=True,
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in _insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     567             _check_write_command_response(result)
#     568
# --> 569         self.__database.client._retryable_write(acknowledged, _insert_command, session)
#     570
# ...

# %%
coll_pwskills.find_one()
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10396\969679100.py in <module>
# ----> 1 coll_pwskills.find_one()
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in find_one(self, filter, *args, **kwargs)
#    1457             filter = {"_id": filter}
#    1458         cursor = self.find(filter, *args, **kwargs)
# -> 1459         for result in cursor.limit(-1):
#    1460             return result
#    1461         return None
#
# ~\anaconda3\lib\site-packages\pymongo\cursor.py in next(self)
#    1246         if self.__empty:
#    1247             raise StopIteration
# -> 1248         if len(self.__data) or self._refresh():
#    1249             return self.__data.popleft()
#    1250         else:
#
# ~\anaconda3\lib\site-packages\pymongo\cursor.py in _refresh(self)
#    1163                 self.__exhaust,
#    1164             )
# ...

# %%
for i in coll_pwskills.find():
     print(i)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10396\3611135719.py in <module>
# ----> 1 for i in coll_pwskills.find():
#       2      print(i)
#
# ~\anaconda3\lib\site-packages\pymongo\cursor.py in next(self)
#    1246         if self.__empty:
#    1247             raise StopIteration
# -> 1248         if len(self.__data) or self._refresh():
#    1249             return self.__data.popleft()
#    1250         else:
#
# ~\anaconda3\lib\site-packages\pymongo\cursor.py in _refresh(self)
#    1163                 self.__exhaust,
#    1164             )
# -> 1165             self.__send_message(q)
#    1166         elif self.__id:  # Get More
#    1167             if self.__limit:
#
# ~\anaconda3\lib\site-packages\pymongo\cursor.py in __send_message(self, operation)
#    1050
#    1051         try:
# ...

# %%
coll_pwskills.update_many()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10396\201060302.py in <module>
# ----> 1 coll_pwskills.update_many()
#
# TypeError: update_many() missing 2 required positional arguments: 'filter' and 'update'
